# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt

f=open('country_vaccinations.csv','r')
data=csv.reader(f)
print(next(data))
next(data)
mx=0
mxdate=''
mndate=''
vacname=''
ctname=''
dic={}
mn=999999
for row in data:
    if row[7]!='':
        vac=round(float(row[7]))
    date=row[2]
    if vac>mx:
        mx=vac
        mxdate=date
    if vac<mn:
        mn=vac
        mndate=date
    vacs=row[12].split(',')
    if row[0]!=ctname:
        for i in vacs:
            if i in dic:
                dic[i]+=1
            else:
                dic[i]=1
        ctname=row[0]


dt=pd.DataFrame(dic.values(),index=dic.keys(),columns=["접종 국가수"])

display(dt)

if(dic.values<10):


print(mx,mn,mxdate,mndate)
# Out:
# ['country', 'iso_code', 'date', 'total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated', 'daily_vaccinations_raw', 'daily_vaccinations', 'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred', 'daily_vaccinations_per_million', 'vaccines', 'source_name', 'source_website']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28088/483913459.py in <module>
#      33         ctname=row[0]
#      34
# ---> 35 dic.values().sort()
#      36 dt=pd.DataFrame(dic.values(),index=dic.keys(),columns=["접종 국가수"])
#      37
#
# AttributeError: 'dict_values' object has no attribute 'sort'
